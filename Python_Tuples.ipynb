# %%
bucket_list_places_tuple = ('Norway', 'Mexico', 'Varanasi', 'Switzerland', 'Iceland', 'Meghalaya')
print(type(bucket_list_places_tuple))
# Out:
# <class 'tuple'>

# %%
bucket_list_places_tuple[1]
# Out:
# 'Mexico'

# %%
bucket_list_places_tuple_list = list(bucket_list_places_tuple)
bucket_list_places_tuple_list.append('Iceland')
print(bucket_list_places_tuple_list)
bucket_list_places_tuple = tuple(bucket_list_places_tuple_list)
print(bucket_list_places_tuple)
print(len(bucket_list_places_tuple))
# Out:
# ['Norway', 'Mexico', 'Varanasi', 'Switzerland', 'Iceland', 'Meghalaya', 'Iceland']
# ('Norway', 'Mexico', 'Varanasi', 'Switzerland', 'Iceland', 'Meghalaya', 'Iceland')
# 7

# %%
new_tuple = ('trial_for_comma',)
print(type(new_tuple))
new_tuple_not_tuple = ('trial_for_comma')
print(type(new_tuple_not_tuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
#Slicing
#To update tuples, convert to list
#Tuples are ordered but unchangeable
